# %%
import scipy.io

# Specify the path to your MATLAB file
matlab_file_path = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\FHR_HUFA_Dataset\FHR_HUFA\DatosFHADepuradoLimpio.mat"

# Load the MATLAB file
data = scipy.io.loadmat(matlab_file_path)

# Now, 'data' is a dictionary containing variables from the MATLAB file
print(data)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri Jun  7 11:59:58 2013', '__version__': '1.0', '__globals__': [], 'pacienteInfo': array([[(array(['02.05.2010,4:45:33:750'], dtype='<U22'), array(['02.05.2010,6:8:13:500'], dtype='<U21'), array([[734260.26597222]]), array(['02-May-2010 06:23:00'], dtype='<U20'), array(['Ces�rea'], dtype='<U7'), array([[7]], dtype=uint8), array([[8]], dtype=uint8), array([[3]], dtype=uint8), array(['caso'], dtype='<U4'), array([[1]], dtype=uint8)),
#         (array(['14.10.2011,6:58:59:0'], dtype='<U20'), array(['14.10.2011,16:53:33:500'], dtype='<U23'), array([[734790.74097222]]), array(['14-Oct-2011 17:47:00'], dtype='<U20'), array(['Eut�cico'], dtype='<U8'), array([[7.04]]), array([[10]], dtype=uint8), array([[1]], dtype=uint8), array(['caso'], dtype='<U4'), array([[1]], dtype=uint8)),
# ...
